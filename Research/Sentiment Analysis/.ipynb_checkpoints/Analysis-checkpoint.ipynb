# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Importing needful libraries and modules

# %%
pip install wordcloud

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from textblob import TextBlob
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string
from wordcloud import WordCloud
import numpy as np

# %% [markdown]
# ### EDA

# %%
# Read the CSV files into pandas DataFrames
df = pd.read_csv('C:/Users/DELL/Desktop/Research/Data/PreprocessedDataset.csv')

# %%
df

# %% [markdown]
# ### Remove unnessary column

# %%
# List of columns to remove
columns_to_remove = ['name', 'url', 'image', 'reviewUrl', 'originalPrice', 'price']

# Remove the columns
df = df.drop(columns=columns_to_remove)

# Verify that the columns have been removed
print(df.columns)
# Out:
# Index(['asin', 'rating', 'date', 'verified', 'helpfulVotes', 'brand',
#        'product', 'averageRating', 'totalReviews', 'mergedReviewText'],
#       dtype='object')

# %% [markdown]
# ##### Piechart for 'verified' column

# %%
# Convert 'verified' column to a more descriptive categorical variable
df['verification_status'] = df['verified'].map({True: 'Verified', False: 'Not Verified'})

# Calculate the count of each verification status
verification_counts = df['verification_status'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 6))
plt.pie(verification_counts, labels=verification_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Verification Status of Reviews')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
plt.show()

# %% [markdown]
# ##### Bar plot for average rating by 'brand

# %%
avg_rating_by_brand = df.groupby('brand')['rating'].mean().sort_values(ascending=False)
plt.figure(figsize=(12, 8))
avg_rating_by_brand.plot(kind='bar')
plt.xlabel('Brand')
plt.ylabel('Average Rating')
plt.title('Average Rating by Brand')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### Distribution of Rating

# %%
# Group by 'brand' and 'rating' to get the count of each rating for each brand
rating_counts = df.groupby(['brand', 'rating']).size().unstack(fill_value=0)

# Iterate over each brand and create a pie chart
for brand in rating_counts.index:
    plt.figure(figsize=(4, 4))
    plt.pie(rating_counts.loc[brand], labels=rating_counts.columns, autopct='%1.1f%%', startangle=90)
    plt.title(f'Distribution of Ratings for {brand}')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle
    plt.show()

# %% [markdown]
# ##### Total review by Brand and Verification Status

# %%
# Group by 'brand' and 'verified' to get the count of reviews for each brand and verification status
reviews_by_brand_verified = df.groupby(['brand', 'verified']).size().unstack(fill_value=0)

# Plotting the bar graph
plt.figure(figsize=(12, 8))
reviews_by_brand_verified.plot(kind='bar', stacked=False)
plt.xlabel('Brand')
plt.ylabel('Total Reviews')
plt.title('Total Reviews by Brand and Verification Status')
plt.xticks(rotation=45)
plt.legend(title='Verification Status', labels=['Non-Verified', 'Verified'])
plt.show()

# %% [markdown]
# ##### Rating distribution for brand according to verified and non verified

# %%
# Filter the data into verified and non-verified subsets
verified_data = df[df['verified'] == True]
non_verified_data = df[df['verified'] == False]

# Calculate the count of each rating for each brand in the verified subset
verified_rating_counts = verified_data.groupby(['brand', 'rating']).size().unstack(fill_value=0)

# Calculate the count of each rating for each brand in the non-verified subset
non_verified_rating_counts = non_verified_data.groupby(['brand', 'rating']).size().unstack(fill_value=0)

# Plotting the pie charts
brands = verified_data['brand'].unique()

for brand in brands:
    plt.figure(figsize=(8, 4))
    
    # Verified reviews pie chart
    plt.subplot(1, 2, 1)
    verified_ratings = verified_rating_counts.loc[brand]
    plt.pie(verified_ratings, labels=verified_ratings.index, autopct='%1.1f%%', startangle=90)
    plt.title(f'Rating Distribution for {brand} (Verified)')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

    # Non-verified reviews pie chart
    plt.subplot(1, 2, 2)
    non_verified_ratings = non_verified_rating_counts.loc[brand]
    plt.pie(non_verified_ratings, labels=non_verified_ratings.index, autopct='%1.1f%%', startangle=90)
    plt.title(f'Rating Distribution for {brand} (Non-Verified)')
    plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# ### Data Preparation

# %%
stop_words = set(stopwords.words('english'))

# %%
def preprocess_text(text):
    text = text.lower()
    tokens = word_tokenize(text)
    tokens = [token for token in tokens if token not in stop_words and token.isalnum()]
    return ' '.join(tokens)

# %%
df['clean_text'] = df['mergedReviewText'].apply(preprocess_text)

# %% [markdown]
# #### Sentiment Analysis with Polarity Score +TextBlob

# %%
def analyze_sentiment_polarity(text):
    blob = TextBlob(text)
    sentiment_score = blob.sentiment.polarity
    if sentiment_score > 0:
        return 'Positive'
    elif sentiment_score < 0:
        return 'Negative'
    else:
        return 'Neutral'

df['sentiment_polarity'] = df['clean_text'].apply(analyze_sentiment_polarity)

# %% [markdown]
# #### Sentiment Analysis with Polarity Score + Subjectivity Score + TextBlob

# %%
def analyze_sentiment_combined(text):
    blob = TextBlob(text)
    polarity_score = blob.sentiment.polarity
    subjectivity_score = blob.sentiment.subjectivity
    combined_score = polarity_score + subjectivity_score
    if combined_score > 0.5:
        return 'Positive'
    elif combined_score < 0.5:
        return 'Negative'
    else:
        return 'Neutral'

df['sentiment_combined'] = df['clean_text'].apply(analyze_sentiment_combined)

# %%
df
# Out:
#              asin  rating                date  verified  helpfulVotes  \
# 0      B0009N5L7K       1       March 5, 2016      True           0.0
# 1      B0009N5L7K       4    February 9, 2006     False           0.0
# 2      B0009N5L7K       5    February 7, 2006     False           0.0
# 3      B0009N5L7K       1   December 20, 2016      True           0.0
# 4      B0009N5L7K       5   December 13, 2009      True           0.0
# ...           ...     ...                 ...       ...           ...
# 67764  B081H6STQQ       5     August 16, 2019     False           1.0
# 67765  B081H6STQQ       5  September 14, 2019     False           1.0
# 67766  B081H6STQQ       5       July 14, 2019     False           0.0
# 67767  B081TJFVCJ       5   December 24, 2019      True           0.0
# 67768  B0825BB7SG       5   December 11, 2019     False           0.0
#
#           brand                                            product  \
# 0      Motorola                                Motorola I265 phone
# 1      Motorola                                Motorola I265 phone
# 2      Motorola                                Motorola I265 phone
# 3      Motorola                                Motorola I265 phone
# 4      Motorola                                Motorola I265 phone
# ...         ...                                                ...
# 67764      Sony  Sony Xperia 1 Unlocked Smartphone and WH1000XM...
# 67765      Sony  Sony Xperia 1 Unlocked Smartphone and WH1000XM...
# 67766      Sony  Sony Xperia 1 Unlocked Smartphone and WH1000XM...
# 67767     Apple  Apple iPhone X, 64GB, Gray - Fully Unlocked (R...
# 67768   Samsung  Straight Talk Samsung Galaxy A10e Smartphone 5...
#
#        averageRating  totalReviews  \
# 0                3.0             7
# 1                3.0             7
# 2                3.0             7
# 3                3.0             7
# 4                3.0             7
# ...              ...           ...
# 67764            4.5            70
# 67765            4.5            70
# 67766            4.5            70
# 67767            5.0             1
# 67768            5.0             1
#
#                                         mergedReviewText verification_status  \
# 0                  Stupid phone DON'T BUY OUT OF SERVICE            Verified
# 1      Exellent Service I have been with nextel for n...        Not Verified
# 2      I love it I just got it and have to say its ea...        Not Verified
# 3      Phones locked 1 star because the phones locked...            Verified
# 4      Excellent product The product has been very go...            Verified
# ...                                                  ...                 ...
# 67764  Awesome Phone, but finger scanner is a big mis...        Not Verified
# 67765  Simply Amazing! I've been an Xperia user for s...        Not Verified
# 67766  great phon3, but many bugs need to fix. still ...        Not Verified
# 67767  Phone is like new Product looks and works like...            Verified
# 67768  Outstanding phone for the price I love the siz...        Not Verified
#
#                                               clean_text sentiment_polarity  \
# 0                               stupid phone buy service           Negative
# 1      exellent service nextel nearly year started ti...           Positive
# 2      love got say easy use hear person talking fine...           Positive
# 3      phones locked 1 star phones locked pay additio...            Neutral
# 4      excellent product product good used cell phone...           Positive
# ...                                                  ...                ...
# 67764  awesome phone finger scanner big miss love cam...           Positive
# 67765  simply amazing xperia user several years say s...           Positive
# 67766  great phon3 many bugs need fix still waiting u...           Positive
# 67767  phone like new product looks works like new mu...           Positive
# 67768  outstanding phone price love size style phone ...           Positive
#
#       sentiment_combined
# 0               Negative
# 1               Positive
# 2               Positive
# 3               Negative
# 4               Positive
# ...                  ...
# 67764           Positive
# 67765           Positive
# 67766           Positive
# 67767           Positive
# 67768           Positive
#
# [67769 rows x 14 columns]

# %% [markdown]
# #### Comparison of Results

# %%
sentiment_comparison = df[['sentiment_polarity', 'sentiment_combined']]
sentiment_comparison.loc[:, 'match'] = sentiment_comparison['sentiment_polarity'] == sentiment_comparison['sentiment_combined']
match_counts = sentiment_comparison['match'].value_counts()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_18188\185376419.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sentiment_comparison.loc[:, 'match'] = sentiment_comparison['sentiment_polarity'] == sentiment_comparison['sentiment_combined']

# %% [markdown]
# #### Visualization

# %%
# Pie chart
plt.figure(figsize=(6, 4))
plt.subplot(1, 2, 1)
plt.pie(match_counts, labels=['Match', 'Mismatch'], colors=['green', 'red'], autopct='%1.1f%%', startangle=90)
plt.title('Sentiment Analysis Match Ratio')

# Bar chart
plt.subplot(1, 2, 2)
plt.bar(match_counts.index.astype(str), match_counts.values, color=['green', 'red'])
plt.xlabel('Match')
plt.ylabel('Count')
plt.title('Comparison of Sentiment Analysis Results')
plt.xticks(range(2), ['Match', 'Mismatch'])

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Analysis

# %%
print(df.columns)
# Out:
# Index(['asin', 'rating', 'date', 'verified', 'helpfulVotes', 'brand',
#        'product', 'averageRating', 'totalReviews', 'mergedReviewText',
#        'verification_status', 'clean_text', 'sentiment_polarity',
#        'sentiment_combined'],
#       dtype='object')

# %% [markdown]
# ##### Sentiment Distribution

# %%
# Pie chart
sentiment_distribution = df['sentiment_combined'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(sentiment_distribution, labels=sentiment_distribution.index, autopct='%1.1f%%', startangle=90)
plt.title('Sentiment Distribution')
plt.show()

# %% [markdown]
# ##### Sentiment by Rating

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='rating', y='sentiment_combined', data=df, estimator=np.mean)
plt.title('Average Sentiment by Rating')
plt.show()

# %% [markdown]
# ##### Sentiment Over Time

# %%
df['date'] = pd.to_datetime(df['date'])
df['month_year'] = df['date'].dt.to_period('M')

plt.figure(figsize=(12, 6))
sns.lineplot(x='month_year', y='sentiment_combined', data=df)
plt.title('Sentiment Over Time')
plt.xlabel('Month')
plt.ylabel('Average Sentiment')
plt.xticks(rotation=45)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# F:\Anaconda\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18188\68971853.py in <module>
#       3
#       4 plt.figure(figsize=(12, 6))
# ----> 5 sns.lineplot(x='month_year', y='sentiment_combined', data=df)
#       6 plt.title('Sentiment Over Time')
#       7 plt.xlabel('Month')
#
# F:\Anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# F:\Anaconda\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     708     p._attach(ax)
#     709
# --> 710     p.plot(ax, kwargs)
#     711     return ax
#     712
#
# F:\Anaconda\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     469         # Loop over the semantic subsets and add to the plot
#     470         grouping_vars = "hue", "size", "style"
# --> 471         for sub_vars, sub_data in self.iter_data(grouping_vars, from_comp_data=True):
#     472
#     473             if self.sort:
#
# F:\Anaconda\lib\site-packages\seaborn\_core.py in iter_data(self, grouping_vars, reverse, from_comp_data)
#     981
#     982         if from_comp_data:
# --> 983             data = self.comp_data
#     984         else:
#     985             data = self.plot_data
#
# F:\Anaconda\lib\site-packages\seaborn\_core.py in comp_data(self)
#    1055                     orig = self.plot_data[var].dropna()
#    1056                 comp_col = pd.Series(index=orig.index, dtype=float, name=var)
# -> 1057                 comp_col.loc[orig.index] = pd.to_numeric(axis.convert_units(orig))
#    1058
#    1059                 if axis.get_scale() == "log":
#
# F:\Anaconda\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     182         coerce_numeric = errors not in ("ignore", "raise")
#     183         try:
# --> 184             values, _ = lib.maybe_convert_numeric(
#     185                 values, set(), coerce_numeric=coerce_numeric
#     186             )
#
# F:\Anaconda\lib\site-packages\pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# TypeError: Invalid object type at position 0

# %% [markdown]
# ##### Sentiment by Brand

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x='brand', y='sentiment_combined', data=df, estimator=np.mean)
plt.title('Average Sentiment by Brand')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### Sentiment by Verification Status

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x='verified', y='sentiment_combined', data=df, estimator=np.mean)
plt.title('Average Sentiment by Verification Status')
plt.xlabel('Verification Status')
plt.ylabel('Sentiment')
plt.xticks([0, 1], ['Not Verified', 'Verified'])
plt.show()

# %% [markdown]
# ##### Word Cloud

# %%
positive_reviews = " ".join(df[df['sentiment_combined'] == 'positive']['clean_text'])
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                stopwords = None, 
                min_font_size = 10).generate(positive_reviews)

plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# ##### Sentiment by Review Length

# %%
df['review_length'] = df['clean_text'].apply(lambda x: len(x.split()))
plt.figure(figsize=(10, 6))
sns.scatterplot(x='review_length', y='sentiment_combined', data=df)
plt.title('Sentiment by Review Length')
plt.xlabel('Review Length')
plt.ylabel('Sentiment')
plt.show()

# %% [markdown]
# ## Natural Language Processing (NLP)
